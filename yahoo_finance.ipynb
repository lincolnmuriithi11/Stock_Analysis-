# %% [markdown]
# # Conducting a fundamental analysis on multiple stocks

# %%
# scraping yahoo finance data FROM THE YF API
import yfinance as yf
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# showing all columns 
pd.set_option('display.max_columns', None)

# %%
# top 10 tickers in S&P
tickers = ['AAPL','MSFT','UNH','META','BRK.B','NVDA','TSLA','AMZN','GOOGL']

# %%
volatility_tickers = ['^VIX','^TNX','^FVX','^TYX']

# %%
info_tickers = []
for i in tickers:
    info_tickers.append (yf.Ticker(i).info)

# %%
info_tickers
# Out:
# [{'zip': '95014',
#   'sector': 'Technology',
#   'fullTimeEmployees': 154000,
# ...

# %%
df = pd.DataFrame(info_tickers)
