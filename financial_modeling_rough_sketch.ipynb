# %% [markdown]
# # Conducting a fundamental analysis on multiple stocks

# %%
# scraping yahoo finance data FROM THE YF API
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import fundamentalanalysis as fa

# showing all columns 
pd.set_option('display.max_columns', None)

# %%
# top 10 tickers in S&P
tickers = ['AAPL','MSFT','UNH','META','BRK.B','NVDA','TSLA','AMZN','GOOGL']

# %%
volatility_tickers = ['^VIX','^TNX','^FVX','^TYX']

# %%
# import fundamentalanalysis as fa

# ticker = "MSFT"
# api_key = "37e40c4b96fac18a00cfbb8d8fc85ca0"

# # Show the available companies
# companies = fa.available_companies(api_key)

# # Collect general company information
# profile = fa.profile(ticker, api_key)

# # Collect recent company quotes
# quotes = fa.quote(ticker, api_key)

# # Collect market cap and enterprise value
# entreprise_value = fa.enterprise(ticker, api_key)

# # Show recommendations of Analysts
# ratings = fa.rating(ticker, api_key)

# # Obtain DCFs over time
# dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")

# # Collect the Balance Sheet statements
# balance_sheet_annually = fa.balance_sheet_statement(ticker, api_key, period="annual")

# # Collect the Income Statements
# income_statement_annually = fa.income_statement(ticker, api_key, period="annual")

# # Collect the Cash Flow Statements
# cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")

# # Show Key Metrics
# key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")

# # Show a large set of in-depth ratios
# financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")

# # Show the growth of the company
# growth_annually = fa.financial_statement_growth(ticker, api_key, period="annual")

# # Download general stock data
# stock_data = fa.stock_data(ticker, period="ytd", interval="1d")

# # Download detailed stock data
# stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2022-08-01")

# # Download dividend history
# dividends = fa.stock_dividend(ticker, api_key, begin="2000-01-01", end="2022-08-01")

# %%
yearly_ratios = pd.read_csv("yearly_ratios.csv")

# %%
yearly_ratios.head()
# Out:
#          date  currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  \
# 0  2022-01-01      1.784607    1.567174   0.146516               81.481137
# 1  2021-01-01      2.079994    1.899196   0.160439               82.609675
# 2  2020-01-01      2.515765    2.330770   0.187747               81.697829
# 3  2019-01-01      2.528839    2.352967   0.163584               85.632574
# 4  2018-01-01      2.900800    2.739861   0.204247               87.582140
#
#    daysOfInventoryOutstanding  operatingCycle  daysOfPayablesOutstanding  \
# 0                   21.800958      103.282095                 110.694334
# 1                   18.420509      101.030183                 105.959852
# 2                   15.010960       96.708789                  99.254525
# 3                   17.548241      103.180814                  79.804941
# 4                   25.333872      112.916012                  82.006753
#
#    cashConversionCycle  grossProfitMargin  operatingProfitMargin  \
# ...

# %%
yearly_ratios.set_index("date", inplace =True)

# %%
yearly_ratios.head()
# Out:
#             currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  \
# date
# 2022-01-01      1.784607    1.567174   0.146516               81.481137
# 2021-01-01      2.079994    1.899196   0.160439               82.609675
# 2020-01-01      2.515765    2.330770   0.187747               81.697829
# 2019-01-01      2.528839    2.352967   0.163584               85.632574
# 2018-01-01      2.900800    2.739861   0.204247               87.582140
#
#             daysOfInventoryOutstanding  operatingCycle  \
# date
# 2022-01-01                   21.800958      103.282095
# 2021-01-01                   18.420509      101.030183
# 2020-01-01                   15.010960       96.708789
# 2019-01-01                   17.548241      103.180814
# 2018-01-01                   25.333872      112.916012
#
#             daysOfPayablesOutstanding  cashConversionCycle  grossProfitMargin  \
# date
# 2022-01-01                 110.694334            -7.412239           0.684017
# ...

# %%
yearly_ratios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 2022-01-01 to 1987-01-01
# Data columns (total 54 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   currentRatio                        36 non-null     float64
#  1   quickRatio                          36 non-null     float64
#  2   cashRatio                           36 non-null     float64
#  3   daysOfSalesOutstanding              36 non-null     float64
#  4   daysOfInventoryOutstanding          36 non-null     float64
#  5   operatingCycle                      36 non-null     float64
#  6   daysOfPayablesOutstanding           36 non-null     float64
#  7   cashConversionCycle                 36 non-null     float64
#  8   grossProfitMargin                   36 non-null     float64
#  9   operatingProfitMargin               36 non-null     float64
#  10  pretaxProfitMargin                  36 non-null     float64
# ...

# %%
yearly_ratios.hist( figsize=(20,15))
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
yearly_ratios.head()

# %%
# yearly_ratios.to_csv("yearly_ratios.csv")

# %%
yearly_ratios.info()
