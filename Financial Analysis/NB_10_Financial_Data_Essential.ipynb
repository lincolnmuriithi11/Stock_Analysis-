# %% [markdown]
# # Financial Data - Essential Workflows

# %% [markdown]
# ## Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT", "SPY"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2019-02-06")
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.426001  42.180119  28.090704  81.321297  19.203468  23.389151
# 2010-01-04  6.526020  43.777546  27.933922  82.284233  19.216942  23.749819
# 2010-01-05  6.537304  45.211349  27.864239  81.290237  18.984486  23.757483
# 2010-01-06  6.433319  46.582809  27.716162  80.762192  18.977747  23.611683
# 2010-01-07  6.421425  48.468555  27.724876  80.482613  18.930580  23.366133
#
#                           Close                    ...       Open             \
#                   SPY      AAPL         BA    DIS  ...         KO       MSFT
# Date                                               ...
# 2009-12-31  87.378426  7.526071  54.130001  32.25  ...  28.790001  30.980000
# 2010-01-04  88.860390  7.643214  56.180000  32.07  ...  28.580000  30.620001
# 2010-01-05  89.095604  7.656429  58.020000  31.99  ...  28.424999  30.850000
# 2010-01-06  89.158348  7.534643  59.779999  31.82  ...  28.174999  30.879999
# 2010-01-07  89.534706  7.520714  62.200001  31.83  ...  28.165001  30.629999
#
#                            Volume                                         \
#                    SPY       AAPL        BA       DIS      IBM        KO
# Date
# 2009-12-31  112.769997  352410800   2189400  19651700  4417676  10848800
# 2010-01-04  112.370003  493729600   6186700  13700400  6438444  13870400
# 2010-01-05  113.260002  601904800   8867800  10307700  7156104  23172400
# 2010-01-06  113.519997  552160000   8836500  10709500  5863144  19264600
# 2010-01-07  113.500000  477131200  14379100   8202100  6109268  13234600
#
#
#                 MSFT        SPY
# Date
# 2009-12-31  31929700   90637900
# 2010-01-04  38409100  118944600
# 2010-01-05  49749600  111579900
# 2010-01-06  58182400  116074400
# 2010-01-07  50559700  131091100
#
# [5 rows x 42 columns]

# %%
stocks.tail()
# Out:
#             Adj Close                                                 \
#                  AAPL          BA         DIS         IBM         KO
# Date
# 2019-01-30  39.939964  376.746307  108.800331  106.921501  42.534222
# 2019-01-31  40.227585  374.705719  110.173546  106.953323  42.774178
# 2019-02-01  40.246918  376.464478  109.956207  106.698730  43.280746
# 2019-02-04  41.390141  385.763641  110.450172  107.565994  43.769535
# 2019-02-05  42.098305  398.570587  111.299789  107.852425  43.778435
#
#                                         Close                          ...  \
#                   MSFT         SPY       AAPL          BA         DIS  ...
# Date                                                                   ...
# 2019-01-30  102.201065  251.490158  41.312500  387.720001  110.129997  ...
# 2019-01-31  100.327675  253.698837  41.610001  385.619995  111.519997  ...
# 2019-02-01   98.742485  253.821014  41.630001  387.429993  111.300003  ...
# 2019-02-04  101.586220  255.606781  42.812500  397.000000  111.800003  ...
# 2019-02-05  103.008080  256.678223  43.544998  410.179993  112.660004  ...
#
#                  Open                             Volume                      \
#                    KO        MSFT         SPY       AAPL        BA       DIS
# Date
# 2019-01-30  47.250000  104.620003  265.100006  244439200  12705300   7853800
# 2019-01-31  47.849998  103.800003  267.510010  162958400   6878500   8351600
# 2019-02-01  48.480000  103.779999  270.149994  130672400   5625700   6557700
# 2019-02-04  48.700001  102.870003  270.109985  125982000   4256600   7037000
# 2019-02-05  49.330002  106.059998  272.440002  144406400   7230400  13619800
#
#
#                 IBM        KO      MSFT        SPY
# Date
# 2019-01-30  4707941  12952500  49471900   92473700
# 2019-01-31  5108664  32181500  55636400  104012100
# 2019-02-01  3981076  19130100  35535700   85782500
# 2019-02-04  4149064  15105700  31315100   60744800
# 2019-02-05  5647249  12651900  27325400   79552800
#
# [5 rows x 42 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2289 entries, 2009-12-31 to 2019-02-05
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2289 non-null   float64
#  1   (Adj Close, BA)    2289 non-null   float64
#  2   (Adj Close, DIS)   2289 non-null   float64
#  3   (Adj Close, IBM)   2289 non-null   float64
#  4   (Adj Close, KO)    2289 non-null   float64
#  5   (Adj Close, MSFT)  2289 non-null   float64
#  6   (Adj Close, SPY)   2289 non-null   float64
#  7   (Close, AAPL)      2289 non-null   float64
#  8   (Close, BA)        2289 non-null   float64
#  9   (Close, DIS)       2289 non-null   float64
#  10  (Close, IBM)       2289 non-null   float64
#  11  (Close, KO)        2289 non-null   float64
#  12  (Close, MSFT)      2289 non-null   float64
#  13  (Close, SPY)       2289 non-null   float64
#  14  (High, AAPL)       2289 non-null   float64
#  15  (High, BA)         2289 non-null   float64
#  16  (High, DIS)        2289 non-null   float64
#  17  (High, IBM)        2289 non-null   float64
#  18  (High, KO)         2289 non-null   float64
#  19  (High, MSFT)       2289 non-null   float64
#  20  (High, SPY)        2289 non-null   float64
#  21  (Low, AAPL)        2289 non-null   float64
#  22  (Low, BA)          2289 non-null   float64
#  23  (Low, DIS)         2289 non-null   float64
#  24  (Low, IBM)         2289 non-null   float64
#  25  (Low, KO)          2289 non-null   float64
#  26  (Low, MSFT)        2289 non-null   float64
#  27  (Low, SPY)         2289 non-null   float64
#  28  (Open, AAPL)       2289 non-null   float64
#  29  (Open, BA)         2289 non-null   float64
#  30  (Open, DIS)        2289 non-null   float64
#  31  (Open, IBM)        2289 non-null   float64
#  32  (Open, KO)         2289 non-null   float64
#  33  (Open, MSFT)       2289 non-null   float64
#  34  (Open, SPY)        2289 non-null   float64
#  35  (Volume, AAPL)     2289 non-null   int64
#  36  (Volume, BA)       2289 non-null   int64
#  37  (Volume, DIS)      2289 non-null   int64
#  38  (Volume, IBM)      2289 non-null   int64
#  39  (Volume, KO)       2289 non-null   int64
#  40  (Volume, MSFT)     2289 non-null   int64
#  41  (Volume, SPY)      2289 non-null   int64
# dtypes: float64(35), int64(7)
# memory usage: 769.0 KB

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.426001  42.180119  28.090704  81.321297  19.203468  23.389151
# 2010-01-04  6.526020  43.777546  27.933922  82.284233  19.216942  23.749819
# 2010-01-05  6.537304  45.211349  27.864239  81.290237  18.984486  23.757483
# 2010-01-06  6.433319  46.582809  27.716162  80.762192  18.977747  23.611683
# 2010-01-07  6.421425  48.468555  27.724876  80.482613  18.930580  23.366133
#
#                           Close                    ...       Open             \
#                   SPY      AAPL         BA    DIS  ...         KO       MSFT
# Date                                               ...
# 2009-12-31  87.378426  7.526071  54.130001  32.25  ...  28.790001  30.980000
# 2010-01-04  88.860390  7.643214  56.180000  32.07  ...  28.580000  30.620001
# 2010-01-05  89.095604  7.656429  58.020000  31.99  ...  28.424999  30.850000
# 2010-01-06  89.158348  7.534643  59.779999  31.82  ...  28.174999  30.879999
# 2010-01-07  89.534706  7.520714  62.200001  31.83  ...  28.165001  30.629999
#
#                            Volume                                         \
#                    SPY       AAPL        BA       DIS      IBM        KO
# Date
# 2009-12-31  112.769997  352410800   2189400  19651700  4417676  10848800
# 2010-01-04  112.370003  493729600   6186700  13700400  6438444  13870400
# 2010-01-05  113.260002  601904800   8867800  10307700  7156104  23172400
# 2010-01-06  113.519997  552160000   8836500  10709500  5863144  19264600
# 2010-01-07  113.500000  477131200  14379100   8202100  6109268  13234600
#
#
#                 MSFT        SPY
# Date
# 2009-12-31  31929700   90637900
# 2010-01-04  38409100  118944600
# 2010-01-05  49749600  111579900
# 2010-01-06  58182400  116074400
# 2010-01-07  50559700  131091100
#
# [5 rows x 42 columns]

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'BA'),  ('Adj Close', 'DIS'),
#         ('Adj Close', 'IBM'),   ('Adj Close', 'KO'), ('Adj Close', 'MSFT'),
#         ('Adj Close', 'SPY'),     ('Close', 'AAPL'),       ('Close', 'BA'),
#             ('Close', 'DIS'),      ('Close', 'IBM'),       ('Close', 'KO'),
#            ('Close', 'MSFT'),      ('Close', 'SPY'),      ('High', 'AAPL'),
#               ('High', 'BA'),       ('High', 'DIS'),       ('High', 'IBM'),
#               ('High', 'KO'),      ('High', 'MSFT'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'BA'),        ('Low', 'DIS'),
#               ('Low', 'IBM'),         ('Low', 'KO'),       ('Low', 'MSFT'),
#               ('Low', 'SPY'),      ('Open', 'AAPL'),        ('Open', 'BA'),
#              ('Open', 'DIS'),       ('Open', 'IBM'),        ('Open', 'KO'),
#             ('Open', 'MSFT'),       ('Open', 'SPY'),    ('Volume', 'AAPL'),
#             ('Volume', 'BA'),     ('Volume', 'DIS'),     ('Volume', 'IBM'),
#             ('Volume', 'KO'),    ('Volume', 'MSFT'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.426001  42.180119  28.090704  81.321297  19.203468  23.389151
# 2010-01-04  6.526020  43.777546  27.933922  82.284233  19.216942  23.749819
# 2010-01-05  6.537304  45.211349  27.864239  81.290237  18.984486  23.757483
# 2010-01-06  6.433319  46.582809  27.716162  80.762192  18.977747  23.611683
# 2010-01-07  6.421425  48.468555  27.724876  80.482613  18.930580  23.366133
#
#                           Close                    ...       Open             \
#                   SPY      AAPL         BA    DIS  ...         KO       MSFT
# Date                                               ...
# 2009-12-31  87.378426  7.526071  54.130001  32.25  ...  28.790001  30.980000
# 2010-01-04  88.860390  7.643214  56.180000  32.07  ...  28.580000  30.620001
# 2010-01-05  89.095604  7.656429  58.020000  31.99  ...  28.424999  30.850000
# 2010-01-06  89.158348  7.534643  59.779999  31.82  ...  28.174999  30.879999
# 2010-01-07  89.534706  7.520714  62.200001  31.83  ...  28.165001  30.629999
#
#                            Volume                                         \
#                    SPY       AAPL        BA       DIS      IBM        KO
# Date
# 2009-12-31  112.769997  352410800   2189400  19651700  4417676  10848800
# 2010-01-04  112.370003  493729600   6186700  13700400  6438444  13870400
# 2010-01-05  113.260002  601904800   8867800  10307700  7156104  23172400
# 2010-01-06  113.519997  552160000   8836500  10709500  5863144  19264600
# 2010-01-07  113.500000  477131200  14379100   8202100  6109268  13234600
#
#
#                 MSFT        SPY
# Date
# 2009-12-31  31929700   90637900
# 2010-01-04  38409100  118944600
# 2010-01-05  49749600  111579900
# 2010-01-06  58182400  116074400
# 2010-01-07  50559700  131091100
#
# [5 rows x 42 columns]

# %%
stocks.swaplevel(axis = 1).sort_index(axis = 1)
# Out:
#                  AAPL                                                         \
#             Adj Close      Close       High        Low       Open     Volume
# Date
# 2009-12-31   6.426001   7.526071   7.619643   7.520000   7.611786  352410800
# 2010-01-04   6.526020   7.643214   7.660714   7.585000   7.622500  493729600
# 2010-01-05   6.537304   7.656429   7.699643   7.616071   7.664286  601904800
# 2010-01-06   6.433319   7.534643   7.686786   7.526786   7.656429  552160000
# 2010-01-07   6.421425   7.520714   7.571429   7.466071   7.562500  477131200
# ...               ...        ...        ...        ...        ...        ...
# 2019-01-30  39.939964  41.312500  41.537498  40.057499  40.812500  244439200
# 2019-01-31  40.227585  41.610001  42.250000  41.139999  41.527500  162958400
# 2019-02-01  40.246918  41.630001  42.244999  41.482498  41.740002  130672400
# 2019-02-04  41.390141  42.812500  42.915001  41.820000  41.852501  125982000
# 2019-02-05  42.098305  43.544998  43.770000  43.087502  43.215000  144406400
#
#                     BA                                      ...        MSFT  \
#              Adj Close       Close        High         Low  ...        High
# Date                                                        ...
# 2009-12-31   42.180119   54.130001   55.220001   54.049999  ...   30.990000
# 2010-01-04   43.777546   56.180000   56.389999   54.799999  ...   31.100000
# 2010-01-05   45.211349   58.020000   58.279999   56.000000  ...   31.100000
# 2010-01-06   46.582809   59.779999   59.990002   57.880001  ...   31.080000
# 2010-01-07   48.468555   62.200001   62.310001   59.020000  ...   30.700001
# ...                ...         ...         ...         ...  ...         ...
# 2019-01-30  376.746307  387.720001  391.970001  380.500000  ...  106.379997
# 2019-01-31  374.705719  385.619995  388.989990  382.079987  ...  105.220001
# 2019-02-01  376.464478  387.429993  392.799988  384.730011  ...  104.099998
# 2019-02-04  385.763641  397.000000  397.070007  388.119995  ...  105.800003
# 2019-02-05  398.570587  410.179993  410.750000  399.549988  ...  107.269997
#
#                                                      SPY              \
#                    Low        Open    Volume   Adj Close       Close
# Date
# 2009-12-31   30.480000   30.980000  31929700   87.378426  111.440002
# 2010-01-04   30.590000   30.620001  38409100   88.860390  113.330002
# 2010-01-05   30.639999   30.850000  49749600   89.095604  113.629997
# 2010-01-06   30.520000   30.879999  58182400   89.158348  113.709999
# 2010-01-07   30.190001   30.629999  50559700   89.534706  114.190002
# ...                ...         ...       ...         ...         ...
# 2019-01-30  104.330002  104.620003  49471900  251.490158  267.579987
# 2019-01-31  103.180000  103.800003  55636400  253.698837  269.929993
# 2019-02-01  102.349998  103.779999  35535700  253.821014  270.059998
# 2019-02-04  102.769997  102.870003  31315100  255.606781  271.959991
# 2019-02-05  105.959999  106.059998  27325400  256.678223  273.100006
#
#
#                   High         Low        Open     Volume
# Date
# 2009-12-31  112.800003  111.389999  112.769997   90637900
# 2010-01-04  113.389999  111.510002  112.370003  118944600
# 2010-01-05  113.680000  112.849998  113.260002  111579900
# 2010-01-06  113.989998  113.430000  113.519997  116074400
# 2010-01-07  114.330002  113.180000  113.500000  131091100
# ...                ...         ...         ...        ...
# 2019-01-30  268.519989  264.250000  265.100006   92473700
# 2019-01-31  270.470001  267.269989  267.510010  104012100
# 2019-02-01  271.200012  269.179993  270.149994   85782500
# 2019-02-04  272.029999  269.359985  270.109985   60744800
# 2019-02-05  273.440002  271.880005  272.440002   79552800
#
# [2289 rows x 42 columns]

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.426001  42.180119  28.090704  81.321297  19.203468  23.389151
# 2010-01-04  6.526020  43.777546  27.933922  82.284233  19.216942  23.749819
# 2010-01-05  6.537304  45.211349  27.864239  81.290237  18.984486  23.757483
# 2010-01-06  6.433319  46.582809  27.716162  80.762192  18.977747  23.611683
# 2010-01-07  6.421425  48.468555  27.724876  80.482613  18.930580  23.366133
#
#                           Close                    ...       Open             \
#                   SPY      AAPL         BA    DIS  ...         KO       MSFT
# Date                                               ...
# 2009-12-31  87.378426  7.526071  54.130001  32.25  ...  28.790001  30.980000
# 2010-01-04  88.860390  7.643214  56.180000  32.07  ...  28.580000  30.620001
# 2010-01-05  89.095604  7.656429  58.020000  31.99  ...  28.424999  30.850000
# 2010-01-06  89.158348  7.534643  59.779999  31.82  ...  28.174999  30.879999
# 2010-01-07  89.534706  7.520714  62.200001  31.83  ...  28.165001  30.629999
#
#                            Volume                                         \
#                    SPY       AAPL        BA       DIS      IBM        KO
# Date
# 2009-12-31  112.769997  352410800   2189400  19651700  4417676  10848800
# 2010-01-04  112.370003  493729600   6186700  13700400  6438444  13870400
# 2010-01-05  113.260002  601904800   8867800  10307700  7156104  23172400
# 2010-01-06  113.519997  552160000   8836500  10709500  5863144  19264600
# 2010-01-07  113.500000  477131200  14379100   8202100  6109268  13234600
#
#
#                 MSFT        SPY
# Date
# 2009-12-31  31929700   90637900
# 2010-01-04  38409100  118944600
# 2010-01-05  49749600  111579900
# 2010-01-06  58182400  116074400
# 2010-01-07  50559700  131091100
#
# [5 rows x 42 columns]

# %%
stocks.tail()
# Out:
#             Adj Close                                                 \
#                  AAPL          BA         DIS         IBM         KO
# Date
# 2019-01-30  39.939964  376.746307  108.800331  106.921501  42.534222
# 2019-01-31  40.227585  374.705719  110.173546  106.953323  42.774178
# 2019-02-01  40.246918  376.464478  109.956207  106.698730  43.280746
# 2019-02-04  41.390141  385.763641  110.450172  107.565994  43.769535
# 2019-02-05  42.098305  398.570587  111.299789  107.852425  43.778435
#
#                                         Close                          ...  \
#                   MSFT         SPY       AAPL          BA         DIS  ...
# Date                                                                   ...
# 2019-01-30  102.201065  251.490158  41.312500  387.720001  110.129997  ...
# 2019-01-31  100.327675  253.698837  41.610001  385.619995  111.519997  ...
# 2019-02-01   98.742485  253.821014  41.630001  387.429993  111.300003  ...
# 2019-02-04  101.586220  255.606781  42.812500  397.000000  111.800003  ...
# 2019-02-05  103.008080  256.678223  43.544998  410.179993  112.660004  ...
#
#                  Open                             Volume                      \
#                    KO        MSFT         SPY       AAPL        BA       DIS
# Date
# 2019-01-30  47.250000  104.620003  265.100006  244439200  12705300   7853800
# 2019-01-31  47.849998  103.800003  267.510010  162958400   6878500   8351600
# 2019-02-01  48.480000  103.779999  270.149994  130672400   5625700   6557700
# 2019-02-04  48.700001  102.870003  270.109985  125982000   4256600   7037000
# 2019-02-05  49.330002  106.059998  272.440002  144406400   7230400  13619800
#
#
#                 IBM        KO      MSFT        SPY
# Date
# 2019-01-30  4707941  12952500  49471900   92473700
# 2019-01-31  5108664  32181500  55636400  104012100
# 2019-02-01  3981076  19130100  35535700   85782500
# 2019-02-04  4149064  15105700  31315100   60744800
# 2019-02-05  5647249  12651900  27325400   79552800
#
# [5 rows x 42 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2289 entries, 2009-12-31 to 2019-02-05
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2289 non-null   float64
#  1   (Adj Close, BA)    2289 non-null   float64
#  2   (Adj Close, DIS)   2289 non-null   float64
#  3   (Adj Close, IBM)   2289 non-null   float64
#  4   (Adj Close, KO)    2289 non-null   float64
#  5   (Adj Close, MSFT)  2289 non-null   float64
#  6   (Adj Close, SPY)   2289 non-null   float64
#  7   (Close, AAPL)      2289 non-null   float64
#  8   (Close, BA)        2289 non-null   float64
#  9   (Close, DIS)       2289 non-null   float64
#  10  (Close, IBM)       2289 non-null   float64
#  11  (Close, KO)        2289 non-null   float64
#  12  (Close, MSFT)      2289 non-null   float64
#  13  (Close, SPY)       2289 non-null   float64
#  14  (High, AAPL)       2289 non-null   float64
#  15  (High, BA)         2289 non-null   float64
#  16  (High, DIS)        2289 non-null   float64
#  17  (High, IBM)        2289 non-null   float64
#  18  (High, KO)         2289 non-null   float64
#  19  (High, MSFT)       2289 non-null   float64
#  20  (High, SPY)        2289 non-null   float64
#  21  (Low, AAPL)        2289 non-null   float64
#  22  (Low, BA)          2289 non-null   float64
#  23  (Low, DIS)         2289 non-null   float64
#  24  (Low, IBM)         2289 non-null   float64
#  25  (Low, KO)          2289 non-null   float64
#  26  (Low, MSFT)        2289 non-null   float64
#  27  (Low, SPY)         2289 non-null   float64
#  28  (Open, AAPL)       2289 non-null   float64
#  29  (Open, BA)         2289 non-null   float64
#  30  (Open, DIS)        2289 non-null   float64
#  31  (Open, IBM)        2289 non-null   float64
#  32  (Open, KO)         2289 non-null   float64
#  33  (Open, MSFT)       2289 non-null   float64
#  34  (Open, SPY)        2289 non-null   float64
#  35  (Volume, AAPL)     2289 non-null   int64
#  36  (Volume, BA)       2289 non-null   int64
#  37  (Volume, DIS)      2289 non-null   int64
#  38  (Volume, IBM)      2289 non-null   int64
#  39  (Volume, KO)       2289 non-null   int64
#  40  (Volume, MSFT)     2289 non-null   int64
#  41  (Volume, SPY)      2289 non-null   int64
# dtypes: float64(35), int64(7)
# memory usage: 769.0 KB

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL           BA          DIS          IBM           KO
# count  2289.000000  2289.000000  2289.000000  2289.000000  2289.000000
# mean     22.868165   130.148071    71.625703   112.836985    30.742611
# std      11.656165    88.687133    29.818073    15.081779     6.489262
# min       5.856373    42.180119    25.536148    76.034492    17.010193
# 25%      13.403691    60.512356    38.741520   105.394394    26.324793
# 50%      21.303015   111.240799    79.018349   114.729446    31.304800
# 75%      28.749037   135.348969    99.532646   124.599289    35.674133
# max      55.894947   398.570587   116.560318   141.874664    44.791576
#
#                                        Close                            ...  \
#               MSFT          SPY         AAPL           BA          DIS  ...
# count  2289.000000  2289.000000  2289.000000  2289.000000  2289.000000  ...
# mean     43.399408   162.578391    25.003036   144.064513    76.563272  ...
# std      24.777086    53.631333    11.727062    88.321575    29.837647  ...
# min      17.819586    80.846313     6.858929    54.130001    29.000000  ...
# 25%      23.278086   110.755707    15.420357    73.739998    43.470001  ...
# 50%      36.294495   166.347702    23.747499   127.639999    85.860001  ...
# 75%      53.869034   195.257431    31.695000   152.250000   104.220001  ...
# max     110.590729   273.088593    58.017502   410.179993   121.690002  ...
#
#               Open                                  Volume                \
#                 KO         MSFT          SPY          AAPL            BA
# count  2289.000000  2289.000000  2289.000000  2.289000e+03  2.289000e+03
# mean     39.367005    48.649244   186.451354  3.187362e+08  4.600220e+06
# std       5.568519    24.463537    52.248319  2.380407e+08  2.440858e+06
# min      25.110001    23.090000   103.110001  4.590360e+07  7.889000e+05
# 25%      36.174999    28.969999   135.410004  1.371600e+08  3.108500e+06
# 50%      40.689999    41.610001   191.779999  2.498160e+08  4.091200e+06
# 75%      43.320000    58.650002   218.050003  4.298896e+08  5.331900e+06
# max      50.820000   115.419998   293.089996  1.880998e+09  4.439180e+07
#
#
#                 DIS           IBM            KO          MSFT           SPY
# count  2.289000e+03  2.289000e+03  2.289000e+03  2.289000e+03  2.289000e+03
# mean   8.780499e+06  5.025249e+06  1.503044e+07  4.154675e+07  1.327855e+08
# std    4.912058e+06  2.642903e+06  6.573916e+06  2.338828e+07  7.565658e+07
# min    2.165700e+06  1.247878e+06  2.996300e+06  7.425600e+06  2.785650e+07
# 25%    6.056300e+06  3.462260e+06  1.082690e+07  2.590170e+07  8.065290e+07
# 50%    7.603600e+06  4.360146e+06  1.354870e+07  3.599450e+07  1.143682e+08
# 75%    9.949000e+06  5.647249e+06  1.754960e+07  5.159570e+07  1.620590e+08
# max    8.704850e+07  3.189275e+07  9.896750e+07  3.193179e+08  7.178287e+08
#
# [8 rows x 42 columns]

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()
# Out:
#                 AAPL         BA    DIS         IBM         KO       MSFT  \
# Date
# 2009-12-31  7.526071  54.130001  32.25  125.143402  28.500000  30.480000
# 2010-01-04  7.643214  56.180000  32.07  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.99  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.82  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.83  123.852776  28.094999  30.450001
#
#                    SPY
# Date
# 2009-12-31  111.440002
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# 2010-01-06  113.709999
# 2010-01-07  114.190002

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
#                 AAPL         BA    DIS         IBM         KO       MSFT  \
# Date
# 2009-12-31  7.526071  54.130001  32.25  125.143402  28.500000  30.480000
# 2010-01-04  7.643214  56.180000  32.07  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.99  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.82  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.83  123.852776  28.094999  30.450001
#
#                    SPY
# Date
# 2009-12-31  111.440002
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# 2010-01-06  113.709999
# 2010-01-07  114.190002

# %%
close.iloc[0,0]
# Out:
# 7.526071071624756

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2009-12-31    100.000000
# 2010-01-04    101.556498
# 2010-01-05    101.732082
# 2010-01-06    100.113899
# 2010-01-07     99.928817
#                  ...
# 2019-01-30    548.925191
# 2019-01-31    552.878125
# 2019-02-01    553.143874
# 2019-02-04    568.855909
# 2019-02-05    578.588719
# Name: AAPL, Length: 2289, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.526071
# BA       54.130001
# DIS      32.250000
# IBM     125.143402
# KO       28.500000
# MSFT     30.480000
# SPY     111.440002
# Name: 2009-12-31 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                   AAPL          BA         DIS         IBM          KO  \
# Date
# 2009-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-04  101.556498  103.787178   99.441860  101.184109  100.070177
# 2010-01-05  101.732082  107.186402   99.193798   99.961805   98.859646
# 2010-01-06  100.113899  110.437830   98.666666   99.312453   98.824565
# 2010-01-07   99.928817  114.908553   98.697674   98.968682   98.578945
# ...                ...         ...         ...         ...         ...
# 2019-01-30  548.925191  716.275621  341.488364  102.658522  167.929827
# 2019-01-31  552.878125  712.396060  345.798439  102.689078  168.877197
# 2019-02-01  553.143874  715.739858  345.116289  102.444620  170.877196
# 2019-02-04  568.855909  733.419531  346.666676  103.277307  172.807018
# 2019-02-05  578.588719  757.768307  349.333345  103.552333  172.842099
#
#                   MSFT         SPY
# Date
# 2009-12-31  100.000000  100.000000
# 2010-01-04  101.541999  101.695979
# 2010-01-05  101.574802  101.965178
# 2010-01-06  100.951447  102.036968
# 2010-01-07   99.901579  102.467696
# ...                ...         ...
# 2019-01-30  349.015744  240.111253
# 2019-01-31  342.618116  242.220017
# 2019-02-01  337.204725  242.336676
# 2019-02-04  346.916009  244.041624
# 2019-02-05  351.771663  245.064609
#
# [2289 rows x 7 columns]

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## The shift() method

# %%
close.head()
# Out:
#                 AAPL         BA    DIS         IBM         KO       MSFT  \
# Date
# 2009-12-31  7.526071  54.130001  32.25  125.143402  28.500000  30.480000
# 2010-01-04  7.643214  56.180000  32.07  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.99  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.82  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.83  123.852776  28.094999  30.450001
#
#                    SPY
# Date
# 2009-12-31  111.440002
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# 2010-01-06  113.709999
# 2010-01-07  114.190002

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2009-12-31  7.526071
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714

# %%
aapl.shift(periods = 1)
# Out:
#                  AAPL
# Date
# 2009-12-31        NaN
# 2010-01-04   7.526071
# 2010-01-05   7.643214
# 2010-01-06   7.656429
# 2010-01-07   7.534643
# ...               ...
# 2019-01-30  38.669998
# 2019-01-31  41.312500
# 2019-02-01  41.610001
# 2019-02-04  41.630001
# 2019-02-05  42.812500
#
# [2289 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1)

# %%
aapl.head()
# Out:
#                 AAPL      lag1
# Date
# 2009-12-31  7.526071       NaN
# 2010-01-04  7.643214  7.526071
# 2010-01-05  7.656429  7.643214
# 2010-01-06  7.534643  7.656429
# 2010-01-07  7.520714  7.534643

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2009-12-31         NaN
# 2010-01-04    0.117143
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
#                 ...
# 2019-01-30    2.642502
# 2019-01-31    0.297501
# 2019-02-01    0.020000
# 2019-02-04    1.182499
# 2019-02-05    0.732498
# Length: 2289, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff
# Date
# 2009-12-31  7.526071       NaN       NaN
# 2010-01-04  7.643214  7.526071  0.117143
# 2010-01-05  7.656429  7.643214  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929

# %%
aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
# Out:
# Date
# 2009-12-31         NaN
# 2010-01-04    1.556498
# 2010-01-05    0.172893
# 2010-01-06   -1.590632
# 2010-01-07   -0.184871
#                 ...
# 2019-01-30    6.833468
# 2019-01-31    0.720123
# 2019-02-01    0.048066
# 2019-02-04    2.840497
# 2019-02-05    1.710945
# Length: 2289, dtype: float64

# %%
aapl["pct_change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2009-12-31  7.526071       NaN       NaN         NaN
# 2010-01-04  7.643214  7.526071  0.117143    1.556498
# 2010-01-05  7.656429  7.643214  0.013215    0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871

# %% [markdown]
# ## The methods diff() and pct_change()

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2009-12-31  7.526071       NaN       NaN         NaN
# 2010-01-04  7.643214  7.526071  0.117143    1.556498
# 2010-01-05  7.656429  7.643214  0.013215    0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871

# %%
aapl.AAPL.diff(periods = 2)
# Out:
# Date
# 2009-12-31         NaN
# 2010-01-04         NaN
# 2010-01-05    0.130358
# 2010-01-06   -0.108571
# 2010-01-07   -0.135715
#                 ...
# 2019-01-30    2.237499
# 2019-01-31    2.940002
# 2019-02-01    0.317501
# 2019-02-04    1.202499
# 2019-02-05    1.914997
# Name: AAPL, Length: 2289, dtype: float64

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2
# Date
# 2009-12-31  7.526071       NaN       NaN         NaN       NaN
# 2010-01-04  7.643214  7.526071  0.117143    1.556498  0.117143
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929
# 2010-01-08  7.570714  7.520714  0.050000    0.664833  0.050000
# 2010-01-11  7.503929  7.570714 -0.066785   -0.882147 -0.066785
# 2010-01-12  7.418571  7.503929 -0.085358   -1.137513 -0.085358
# 2010-01-13  7.523214  7.418571  0.104643    1.410553  0.104643
# 2010-01-14  7.479643  7.523214 -0.043571   -0.579154 -0.043571

# %%
aapl.Diff.equals(aapl.Diff2)
# Out:
# True

# %%
aapl["pct_change2"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2  pct_change2
# Date
# 2009-12-31  7.526071       NaN       NaN         NaN       NaN          NaN
# 2010-01-04  7.643214  7.526071  0.117143    1.556498  0.117143     1.556498
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215     0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786    -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929    -0.184871

# %%
aapl.AAPL.resample("BM").last().pct_change(periods =1).mul(100)
# Out:
# Date
# 2009-12-31          NaN
# 2010-01-29    -8.859672
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
#                 ...
# 2018-10-31    -3.047756
# 2018-11-30   -18.404459
# 2018-12-31   -11.669838
# 2019-01-31     5.515403
# 2019-02-28     4.650319
# Freq: BM, Name: AAPL, Length: 111, dtype: float64

# %% [markdown]
# ## Measuring Stock Perfromance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2009-12-31  7.526071
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714

# %%
aapl.pct_change().dropna()
# Out:
#                 AAPL
# Date
# 2010-01-04  0.015565
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# ...              ...
# 2019-01-30  0.068335
# 2019-01-31  0.007201
# 2019-02-01  0.000481
# 2019-02-04  0.028405
# 2019-02-05  0.017109
#
# [2288 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  0.015565
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2288 entries, 2010-01-04 to 2019-02-05
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2288 non-null   float64
# dtypes: float64(1)
# memory usage: 35.8 KB

# %%
ret.plot(kind = "hist", figsize = (12 ,8), bins = 100)
plt.show()

# %%
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.000902
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000269
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    0.016394
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.016394
# dtype: float64

# %%
ann_mean_Return = ret.mean() * 252
ann_mean_Return
# Out:
# AAPL    0.227324
# dtype: float64

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns
# Out:
# AAPL    0.067726
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns
# Out:
# AAPL    0.260243
# dtype: float64

# %%
ret.std() * np.sqrt(252)
# Out:
# AAPL    0.260243
# dtype: float64

# %% [markdown]
# ## Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
#                 AAPL         BA    DIS         IBM         KO       MSFT  \
# Date
# 2009-12-31  7.526071  54.130001  32.25  125.143402  28.500000  30.480000
# 2010-01-04  7.643214  56.180000  32.07  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.99  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.82  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.83  123.852776  28.094999  30.450001
#
#                    SPY
# Date
# 2009-12-31  111.440002
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# 2010-01-06  113.709999
# 2010-01-07  114.190002

# %%
close.pct_change().dropna()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT  \
# Date
# 2010-01-04  0.015565  0.037872 -0.005581  0.011841  0.000702  0.015420
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# ...              ...       ...       ...       ...       ...       ...
# 2019-01-30  0.068335  0.062509 -0.006943  0.000372  0.009705  0.033417
# 2019-01-31  0.007201 -0.005416  0.012621  0.000298  0.005641 -0.018330
# 2019-02-01  0.000481  0.004694 -0.001973 -0.002381  0.011843 -0.015800
# 2019-02-04  0.028405  0.024701  0.004492  0.008128  0.011294  0.028799
# 2019-02-05  0.017109  0.033199  0.007692  0.002663  0.000203  0.013997
#
#                  SPY
# Date
# 2010-01-04  0.016960
# 2010-01-05  0.002647
# 2010-01-06  0.000704
# 2010-01-07  0.004221
# 2010-01-08  0.003328
# ...              ...
# 2019-01-30  0.015831
# 2019-01-31  0.008782
# 2019-02-01  0.000482
# 2019-02-04  0.007035
# 2019-02-05  0.004192
#
# [2288 rows x 7 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT  \
# Date
# 2010-01-04  0.015565  0.037872 -0.005581  0.011841  0.000702  0.015420
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
#
#                  SPY
# Date
# 2010-01-04  0.016960
# 2010-01-05  0.002647
# 2010-01-06  0.000704
# 2010-01-07  0.004221
# 2010-01-08  0.003328

# %%
ret.describe().T.loc[:, ["mean", "std"]]
# Out:
#           mean       std
# AAPL  0.000902  0.016394
# BA    0.001006  0.015504
# DIS   0.000633  0.013136
# IBM   0.000093  0.012429
# KO    0.000282  0.009205
# MSFT  0.000656  0.014579
# SPY   0.000437  0.009453

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.000902  0.016394
# BA    0.001006  0.015504
# DIS   0.000633  0.013136
# IBM   0.000093  0.012429
# KO    0.000282  0.009205
# MSFT  0.000656  0.014579
# SPY   0.000437  0.009453

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary
# Out:
#           mean       std
# AAPL  0.227324  0.260243
# BA    0.253438  0.246122
# DIS   0.159602  0.208534
# IBM   0.023376  0.197305
# KO    0.070970  0.146129
# MSFT  0.165324  0.231441
# SPY   0.110023  0.150056

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ## Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT  \
# Date
# 2010-01-04  0.015565  0.037872 -0.005581  0.011841  0.000702  0.015420
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
#
#                  SPY
# Date
# 2010-01-04  0.016960
# 2010-01-05  0.002647
# 2010-01-06  0.000704
# 2010-01-07  0.004221
# 2010-01-08  0.003328

# %%
ret.cov()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000269  0.000104  0.000080  0.000076  0.000040  0.000107  0.000091
# BA    0.000104  0.000240  0.000105  0.000089  0.000057  0.000101  0.000102
# DIS   0.000080  0.000105  0.000173  0.000073  0.000052  0.000086  0.000089
# IBM   0.000076  0.000089  0.000073  0.000154  0.000047  0.000088  0.000075
# KO    0.000040  0.000057  0.000052  0.000047  0.000085  0.000051  0.000050
# MSFT  0.000107  0.000101  0.000086  0.000088  0.000051  0.000213  0.000094
# SPY   0.000091  0.000102  0.000089  0.000075  0.000050  0.000094  0.000089

# %%
ret.corr()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.410269  0.372869  0.374978  0.266914  0.447375  0.585704
# BA    0.410269  1.000000  0.517183  0.459619  0.400967  0.447268  0.699296
# DIS   0.372869  0.517183  1.000000  0.448426  0.432642  0.450547  0.712962
# IBM   0.374978  0.459619  0.448426  1.000000  0.407340  0.486098  0.639858
# KO    0.266914  0.400967  0.432642  0.407340  1.000000  0.378116  0.579411
# MSFT  0.447375  0.447268  0.450547  0.486098  0.378116  1.000000  0.683649
# SPY   0.585704  0.699296  0.712962  0.639858  0.579411  0.683649  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()
