# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL","BA", "KO", "IBM","DIS", "MSFT"]

# %%
stocks = yf.download(ticker, start = "2010-01-01" )
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.426000  42.180107  28.090708  81.321312  19.203470  23.389149
# 2010-01-04  6.526021  43.777561  27.933920  82.284210  19.216949  23.749817
# 2010-01-05  6.537304  45.211338  27.864237  81.290245  18.984488  23.757488
# 2010-01-06  6.433319  46.582802  27.716164  80.762184  18.977739  23.611691
# 2010-01-07  6.421425  48.468563  27.724873  80.482613  18.930580  23.366135
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526071  54.130001  32.25  125.143402  ...  32.27  126.586998
# 2010-01-04  7.643214  56.180000  32.07  126.625237  ...  32.50  125.411087
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                                                \
#                   AAPL          BA        DIS         IBM         KO
# Date
# 2022-10-11  138.979996  131.570007  93.099998  117.800003  54.480000
# 2022-10-12  138.339996  130.419998  93.410004  117.570000  55.139999
# 2022-10-13  142.990005  132.399994  96.639999  121.790001  55.869999
# 2022-10-14  138.380005  133.149994  94.449997  120.040001  54.980000
# 2022-10-17  142.410004  136.089996  97.330002  121.519997  55.689999
#
#                              Close                                     ...  \
#                   MSFT        AAPL          BA        DIS         IBM  ...
# Date                                                                   ...
# 2022-10-11  225.410004  138.979996  131.570007  93.099998  117.800003  ...
# 2022-10-12  225.750000  138.339996  130.419998  93.410004  117.570000  ...
# 2022-10-13  234.240005  142.990005  132.399994  96.639999  121.790001  ...
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3221 entries, 2009-12-31 to 2022-10-17
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3221 non-null   float64
#  1   (Adj Close, BA)    3221 non-null   float64
#  2   (Adj Close, DIS)   3221 non-null   float64
#  3   (Adj Close, IBM)   3221 non-null   float64
#  4   (Adj Close, KO)    3221 non-null   float64
#  5   (Adj Close, MSFT)  3221 non-null   float64
#  6   (Close, AAPL)      3221 non-null   float64
#  7   (Close, BA)        3221 non-null   float64
#  8   (Close, DIS)       3221 non-null   float64
#  9   (Close, IBM)       3221 non-null   float64
#  10  (Close, KO)        3221 non-null   float64
#  11  (Close, MSFT)      3221 non-null   float64
#  12  (High, AAPL)       3221 non-null   float64
#  13  (High, BA)         3221 non-null   float64
#  14  (High, DIS)        3221 non-null   float64
# ...

# %%
# transfer to csv
stocks.to_csv("stocks.csv", )

# %%
# fixing the index back to date
stocks = pd.read_csv("stocks.csv", header= [0,1], index_col = [0], parse_dates = [0])

# %%
# removing the multi index column names
stocks.columns = stocks.columns.to_flat_index()
stocks.head()
# Out:
#             (Adj Close, AAPL)  (Adj Close, BA)  (Adj Close, DIS)  \
# Date
# 2009-12-31           6.426000        42.180107         28.090708
# 2010-01-04           6.526021        43.777561         27.933920
# 2010-01-05           6.537304        45.211338         27.864237
# 2010-01-06           6.433319        46.582802         27.716164
# 2010-01-07           6.421425        48.468563         27.724873
#
#             (Adj Close, IBM)  (Adj Close, KO)  (Adj Close, MSFT)  \
# Date
# 2009-12-31         81.321312        19.203470          23.389149
# 2010-01-04         82.284210        19.216949          23.749817
# 2010-01-05         81.290245        18.984488          23.757488
# 2010-01-06         80.762184        18.977739          23.611691
# 2010-01-07         80.482613        18.930580          23.366135
#
#             (Close, AAPL)  (Close, BA)  (Close, DIS)  (Close, IBM)  ...  \
# Date                                                                ...
# ...

# %%
#to get back multi inndex 
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.426000  42.180107  28.090708  81.321312  19.203470  23.389149
# 2010-01-04  6.526021  43.777561  27.933920  82.284210  19.216949  23.749817
# 2010-01-05  6.537304  45.211338  27.864237  81.290245  18.984488  23.757488
# 2010-01-06  6.433319  46.582802  27.716164  80.762184  18.977739  23.611691
# 2010-01-07  6.421425  48.468563  27.724873  80.482613  18.930580  23.366135
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526071  54.130001  32.25  125.143402  ...  32.27  126.586998
# 2010-01-04  7.643214  56.180000  32.07  126.625237  ...  32.50  125.411087
# ...

# %%
# pass 0 to axis level if you want to get the index
stocks.swaplevel(axis= 1)
# Out:
#                   AAPL          BA        DIS         IBM         KO  \
#              Adj Close   Adj Close  Adj Close   Adj Close  Adj Close
# Date
# 2009-12-31    6.426000   42.180107  28.090708   81.321312  19.203470
# 2010-01-04    6.526021   43.777561  27.933920   82.284210  19.216949
# 2010-01-05    6.537304   45.211338  27.864237   81.290245  18.984488
# 2010-01-06    6.433319   46.582802  27.716164   80.762184  18.977739
# 2010-01-07    6.421425   48.468563  27.724873   80.482613  18.930580
# ...                ...         ...        ...         ...        ...
# 2022-10-11  138.979996  131.570007  93.099998  117.800003  54.480000
# 2022-10-12  138.339996  130.419998  93.410004  117.570000  55.139999
# 2022-10-13  142.990005  132.399994  96.639999  121.790001  55.869999
# 2022-10-14  138.380005  133.149994  94.449997  120.040001  54.980000
# 2022-10-17  142.410004  136.089996  97.330002  121.519997  55.689999
#
# ...

# %%
stocks.swaplevel(axis= 1).sort_index(axis = 1)
# Out:
#                   AAPL                                                  \
#              Adj Close       Close        High         Low        Open
# Date
# 2009-12-31    6.426000    7.526071    7.619643    7.520000    7.611786
# 2010-01-04    6.526021    7.643214    7.660714    7.585000    7.622500
# 2010-01-05    6.537304    7.656429    7.699643    7.616071    7.664286
# 2010-01-06    6.433319    7.534643    7.686786    7.526786    7.656429
# 2010-01-07    6.421425    7.520714    7.571429    7.466071    7.562500
# ...                ...         ...         ...         ...         ...
# 2022-10-11  138.979996  138.979996  141.350006  138.220001  139.899994
# 2022-10-12  138.339996  138.339996  140.360001  138.160004  139.130005
# 2022-10-13  142.990005  142.990005  143.589996  134.369995  134.990005
# 2022-10-14  138.380005  138.380005  144.520004  138.190002  144.309998
# 2022-10-17  142.410004  142.410004  142.899994  140.270004  141.070007
#
# ...
